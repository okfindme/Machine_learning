# %%
import pandas as pd 
import numpy as np 
from sklearn.datasets import load_diabetes

# %%
feature , target = load_diabetes(return_X_y=True) # it by default gives features and target seperately as numpy array
df_like = load_diabetes(as_frame=True)#give me the data as a pandas DataFrame instead of a numpy array"

# %%
type(target)
# Out:
# numpy.ndarray

# %%
# converting the dataframe like object into the real dataframe.
x = df_like.data
y = df_like.target
data_frame = x.copy()
data_frame["target"] = y
print(data_frame)
# Out:
#           age       sex       bmi  ...        s5        s6  target
# 0    0.038076  0.050680  0.061696  ...  0.019907 -0.017646   151.0
# 1   -0.001882 -0.044642 -0.051474  ... -0.068332 -0.092204    75.0
# 2    0.085299  0.050680  0.044451  ...  0.002861 -0.025930   141.0
# 3   -0.089063 -0.044642 -0.011595  ...  0.022688 -0.009362   206.0
# 4    0.005383 -0.044642 -0.036385  ... -0.031988 -0.046641   135.0
# ..        ...       ...       ...  ...       ...       ...     ...
# 437  0.041708  0.050680  0.019662  ...  0.031193  0.007207   178.0
# 438 -0.005515  0.050680 -0.015906  ... -0.018114  0.044485   104.0
# 439  0.041708  0.050680 -0.015906  ... -0.046883  0.015491   132.0
# 440 -0.045472 -0.044642  0.039062  ...  0.044529 -0.025930   220.0
# 441 -0.045472 -0.044642 -0.073030  ... -0.004222  0.003064    57.0
#
# [442 rows x 11 columns]

# %% [markdown]
# # first using inbuilt multi-regression of sklearn_library

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
x_train , x_test , y_train , y_test = train_test_split(feature , target , test_size=0.3 , random_state= 42 )

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score
r2_score(y_true=y_test , y_pred=y_pred)
# Out:
# 0.4772897164322618

# %%
lr.coef_

"""
Positive coefficient means:

as this feature increases, the target increases

Negative coefficient means:

as this feature increases, the target decreases

**Think of it like this:**
```
y = c1*x1 + c2*x2 + c3*x3 + bias

if c2 = -5.3
meaning for every 1 unit increase in x2,
y DECREASES by 5.3 units
"""
# Out:
# '\nPositive coefficient means:\n\nas this feature increases, the target increases\n\nNegative coefficient means:\n\nas this feature increases, the target decreases\n\n**Think of it like this:**\n```\ny = c1*x1 + c2*x2 + c3*x3 + bias\n\nif c2 = -5.3\nmeaning for every 1 unit increase in x2,\ny DECREASES by 5.3 units\n'

# %% [markdown]
# ## creating our own linear_regression

# %%
class Dummy_lr :
    def __init__(self):
        self.coef_ = None
        self.intercept_ = None
        
    def fit(self,X_train,y_train):
        X_train = np.insert(X_train,0,1,axis=1)
        
        # calcuate the coeffs
        betas = np.linalg.inv(np.dot(X_train.T,X_train)).dot(X_train.T).dot(y_train)
        #as 1st value is intercept
        # equation to find the coeficient =  (XᵀX)⁻¹ Xᵀ y
        self.intercept_ = betas[0]
        self.coef_ = betas[1:]
    
    def predict(self,X_test):
        y_pred = np.dot(X_test,self.coef_) + self.intercept_
        return y_pred

# %% [markdown]
# ### why adding 1s in the 1st column ??
# Adds a column of **1s** at the beginning of X. Why?
#
# Because our equation is:
# ```
# y = b0 + b1*x1 + b2*x2
# ```
# To handle `b0` (intercept) inside matrix math, we treat it as:
# ```
# y = b0*1 + b1*x1 + b2*x2
# ```
# So we add a dummy column of 1s to represent that!
# ```
# Before insert:          After insert:
# [x1, x2, x3]    →    [1, x1, x2, x3]
# [x1, x2, x3]    →    [1, x1, x2, x3]

# %%
lr = Dummy_lr()
lr.fit(x_train,y_train)

# %%
y_pred = lr.predict(x_test)
r2_score(y_pred=y_pred , y_true=y_test)
# Out:
# 0.5119571119350508
