# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 

# machine learning library 
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %% [markdown]
# # importing the data set and doing pre-processing

# %%
df = pd.read_csv("Cars_Data.csv")

# %%
df.head(3)
# Out:
#                            name  year  ...                 torque  seats
# 0        Maruti Swift Dzire VDI  2014  ...         190Nm@ 2000rpm    5.0
# 1  Skoda Rapid 1.5 TDI Ambition  2014  ...    250Nm@ 1500-2500rpm    5.0
# 2      Honda City 2017-2020 EXi  2006  ...  12.7@ 2,700(kgm@ rpm)    5.0
#
# [3 rows x 13 columns]

# %%
# identifying the number of unique car models.
df["name"].value_counts()
df["name"].nunique() # total 2058 unique car names are there
# Out:
# 2058

# %%
for unique_value in df.columns :
    print("column_name = ",unique_value)
    print(df[unique_value].unique())
    print("\n\n\n\n")
# Out:
# column_name =  name
# ['Maruti Swift Dzire VDI' 'Skoda Rapid 1.5 TDI Ambition'
#  'Honda City 2017-2020 EXi' ... 'Tata Nexon 1.5 Revotorq XT'
#  'Ford Freestyle Titanium Plus Diesel BSIV'
#  'Toyota Innova 2.5 GX (Diesel) 8 Seater BS IV']
#
#
#
#
#
# column_name =  year
# [2014 2006 2010 2007 2017 2001 2011 2013 2005 2009 2016 2012 2002 2015
#  2018 2003 2019 2008 2020 1999 2000 1983 2004 1996 1994 1995 1998 1997
#  1991]
#
#
#
#
#
# column_name =  selling_price
# [  450000   370000   158000   225000   130000   440000    96000    45000
#    350000   200000   500000    92000   280000   180000   400000   778000
#    150000   680000   174000   950000   525000   600000   575000   275000
#    300000   220000   254999   670000    70000   730000   650000   330000
#    366000  1149000   425000  2100000   925000   675000   819999   390000
#   1500000   700000  1450000  1090000   850000  1650000  1750000  1590000
#   1689999  1425000   265000   190000   630000   540000   448000   745000
# ...

# %%
# droping the touque as it does not play the important role.
df.drop(columns=["torque"] , inplace=True)

# %% [markdown]
# ### preprocessing

# %%
df.isnull().sum()
# there are 5 columns with null values
# Out:
# name               0
# year               0
# selling_price      0
# km_driven          0
# fuel               0
# seller_type        0
# transmission       0
# owner              0
# mileage          221
# engine           221
# max_power        215
# seats            221
# dtype: int64

# %%
# as null values are very less we are gonna replace it.
df.dropna(inplace=True)

# %%
# droping the duplicate values
df.drop_duplicates(inplace=True)

# %% [markdown]
# ### converting the categorical columns , cleaning them into the single value

# %%
# the funciton will spilt the car name and then store the frist name and remove its spaces
def get_brand_name(car_name:str):
    brand_name = car_name.split(" ")[0]
    brand_name = brand_name.strip(" ")
    return brand_name

# %%
# when column is specified , it performs that function on every cell in that column
df["name"] = df["name"].apply(get_brand_name)
df.head(2)
# Out:
#      name  year  selling_price  ...   engine   max_power seats
# 0  Maruti  2014         450000  ...  1248 CC      74 bhp   5.0
# 1   Skoda  2014         370000  ...  1498 CC  103.52 bhp   5.0
#
# [2 rows x 12 columns]

# %%
# as we also want first word from the milage column this function will work 
df["mileage"] = df["mileage"].apply(get_brand_name)
df["max_power"] = df["max_power"].apply(get_brand_name)
df["engine"] = df["engine"].apply(get_brand_name)
df.head(2)
# Out:
#      name  year  selling_price  km_driven  ... mileage engine max_power seats
# 0  Maruti  2014         450000     145500  ...    23.4   1248        74   5.0
# 1   Skoda  2014         370000     120000  ...   21.14   1498    103.52   5.0
#
# [2 rows x 12 columns]

# %%
for string in df['max_power']:
    if string == "":
        print("there is empty string")
# Out:
# there is empty string

# %%
df['max_power'].replace([""],[0],inplace=True)
# Out:
# C:\Users\adity\AppData\Local\Temp\ipykernel_16496\1667357751.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['max_power'].replace([""],[0],inplace=True)

# %%
df['mileage'].astype(float)
df['max_power'].astype(float)
df['engine'].astype(float)
# Out:
# 0       1248.0
# 1       1498.0
# 2       1497.0
# 3       1396.0
# 4       1298.0
#          ...
# 8121     998.0
# 8122    1396.0
# 8123    1197.0
# 8124    1493.0
# 8125    1248.0
# Name: engine, Length: 6718, dtype: float64

# %% [markdown]
# ### converting the categorical column into numerical column

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()

# %%
# name fuel  seller_type transmission owner => converted all these into numerical values

df["name"] = le.fit_transform(df['name'])
df["fuel"] = le.fit_transform(df["fuel"])
df["seller_type"] = le.fit_transform(df["seller_type"])
df["transmission"] = le.fit_transform(df["transmission"])
df["owner"] = le.fit_transform(df["owner"])

# %%
df.reset_index(inplace=True,drop=True)

# %% [markdown]
# ## Train_test_split

# %%
input_data = df.drop(columns=["selling_price"])
output_data = df["selling_price"]

# %%
x_train , x_test , y_train , y_test = train_test_split(input_data,output_data , test_size=0.2 , random_state=42)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6718 entries, 0 to 6717
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           6718 non-null   int64
#  1   year           6718 non-null   int64
#  2   selling_price  6718 non-null   int64
#  3   km_driven      6718 non-null   int64
#  4   fuel           6718 non-null   int64
#  5   seller_type    6718 non-null   int64
#  6   transmission   6718 non-null   int64
#  7   owner          6718 non-null   int64
#  8   mileage        6718 non-null   object
#  9   engine         6718 non-null   object
#  10  max_power      6718 non-null   object
#  11  seats          6718 non-null   float64
# dtypes: float64(1), int64(8), object(3)
# memory usage: 629.9+ KB

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
r2_score(y_true= y_test,y_pred= y_pred)
# Out:
# 0.6670893594625873
