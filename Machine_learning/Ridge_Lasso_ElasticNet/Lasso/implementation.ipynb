# %%
from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.linear_model import Lasso
from sklearn.datasets import load_diabetes
import numpy as np

# %%
x , y = load_diabetes(return_X_y=True)
x_train , x_test , y_train , y_test = train_test_split(x,y, test_size=0.2 ,random_state=4 )

# %%
Ls = Lasso(alpha=0.1)

# %%
Ls.fit(x_train , y_train)
sk_pred = Ls.predict(x_test)

# %%
r2_score(y_test , sk_pred)
# Out:
# 0.4724963600006995

# %%
print("coef_ of ls  ",Ls.coef_)
print("intercept_  = " , Ls.intercept_)
# Out:
# coef_ of ls   [   0.         -198.9160636   480.67291811  330.6284946   -26.56749333
#    -0.         -209.48138737    0.          490.4097521     0.50094089]
# intercept_  =  151.04379849910887

# %% [markdown]
# ## self implementation of lasso

# %%
class My_lasso( ):
    def __init__(self, lr = 0.01 , epoches = 1000 , alpha = 0.1):
        self.lr = lr 
        self.epoches = epoches 
        self.slope = None
        self.intercept = None 
        self.alpha = alpha

    def fit(self , x , y ):
        self.slope = np.zeros(shape=x.shape[1])
        self.intercept = 0

        for i in range(self.epoches):

            y_pred = np.dot(x, self.slope) + self.intercept
