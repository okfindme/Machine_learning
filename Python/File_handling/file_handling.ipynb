# %%
# reading a file 
with open("test.txt",mode='r') as file:
    print(file.read())
# Out:
# we are testing the file

# %%
with open('test.txt',mode='r') as file:
    for line in file:
        print(line) # as we can see , we are having the new line char also printed causing the new line.
        print(line.strip())
# Out:
# we are testing the file
#
# we are testing the file
# 2nd line in a text file
#
# 2nd line in a text file
# 3rd line in a text file
#
# 3rd line in a text file
# 4th line in a text file
# 4th line in a text file
