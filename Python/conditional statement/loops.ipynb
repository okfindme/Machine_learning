# %%
for i in range(5):
    print(i)
# Out:
# 0
# 1
# 2
# 3
# 4

# %%
#reversing a number 
#starting from 10 to 1 and every step is decreasing by 1
for i in range(10,1,-1):
    print(i)
# Out:
# 10
# 9
# 8
# 7
# 6
# 5
# 4
# 3
# 2

# %% [markdown]
# working with the strings

# %%
name = "aditya"
for i in name:
    print(i)
# Out:
# a
# d
# i
# t
# y
# a

# %%
for num in range(1,101):
    if num>1:
        for i in range(2,num):
            if num%i==0:
                break
        else :
            print(num)
