# %% [markdown]
# ### library
# collection of many modules and packages that are bundled together.

# %%
# file and directory
import os 
print(os.getcwd()) # it prints the current working directory
# Out:
# a:\FINAL_CODING_FILE\Python\modules

# %%
#shutil (Shell Utilities) is a built-in Python module used for high-level file and directory operations.
import shutil
shutil.copyfile("test.txt","destination.txt") #it will create the file if not existed.
# Out:
# 'destination.txt'

# %%
# data serialisation.
# library for json.
import json
data = {
    "name" : "aditya",
    "course" : "bca"
}
json_str = json.dumps(data)
print(json_str)
print(type(json_str))
# Out:
# {"name": "aditya", "course": "bca"}
# <class 'str'>

# %%
# working with csv file 
import csv

with open("example.csv",mode="w",newline='') as file:
    writer = csv.writer(file)
    writer.writerow(["name","age"])
    writer.writerow(["aditya","7"])

with open("example.csv",mode='r') as file:
    #content = file.read()
    #print(content)
    csv_content = csv.reader(file)
    for lines in csv_content:
        print(lines)
# Out:
# ['name', 'age']
# ['aditya', '7']
