# %%
import math
math.sqrt(25)
# Out:
# 5.0

# %%
#these self made packages should be in same folder
# declaring __init__.py in the package folder is important as it tells, it needs to be treated as package.
from packages.Maths import addition
addition(1,2)
# Out:
# 3
